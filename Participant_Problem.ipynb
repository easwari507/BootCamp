# %% [markdown]
# # Guided Project: PDF-Based Knowledge Base RAG System
#
# ## Participant Problem Google Colab Notebook
#
# ### Objective
# Build a simple Retrieval-Augmented Generation (RAG) application that allows users to ask questions about a PDF document and receive context-based answers.
#
# ### Required pipeline
# **PDF → PDF Loader → Chunking → Embeddings → ChromaDB → Retrieval → GPT-4o-mini → Answer**
#
# ### Important
# - libraries installation or environment setup is required.
# - The OpenAI API key will be provided.
# - Use the supplied PDF in `04_DATA/sample_knowledge_base.pdf`.
# - Complete the tasks in order.
# - Type or copy/paste the code into the cells and run them.

# %% [markdown]
# # Project Architecture
#
# The application implements the following end-to-end Retrieval-Augmented Generation (RAG) pipeline:
#
# ```text
#                          USER / PARTICIPANT
#                                 │
#                                 ▼
#                     ┌─────────────────────┐
#                     │     PDF Upload      │
#                     │   / PDF File Path   │
#                     └──────────┬──────────┘
#                                │
#                                ▼
#                     ┌─────────────────────┐
#                     │   LangChain PDF     │
#                     │   Document Loader   │
#                     │    PyPDFLoader      │
#                     └──────────┬──────────┘
#                                │
#                                ▼
#                     ┌─────────────────────┐
#                     │    Text Chunking    │
#                     │                     │
#                     │ RecursiveCharacter  │
#                     │ TextSplitter         │
#                     │                     │
#                     │ Chunk Size = 1000   │
#                     │ Overlap = 200       │
#                     └──────────┬──────────┘
#                                │
#                                ▼
#                     ┌─────────────────────┐
#                     │     Embeddings      │
#                     │                     │
#                     │ text-embedding-     │
#                     │ 3-small             │
#                     └──────────┬──────────┘
#                                │
#                                ▼
#                     ┌─────────────────────┐
#                     │      ChromaDB       │
#                     │                     │
#                     │ Vector Embeddings   │
#                     │ + Document Metadata │
#                     └──────────┬──────────┘
#                                │
#                                │
#               USER QUESTION   │
#                     │          │
#                     ▼          │
#           ┌────────────────┐   │
#           │ Query / Search │   │
#           └───────┬────────┘   │
#                   │            │
#                   ▼            ▼
#              ┌─────────────────────┐
#              │      Retriever       │
#              │                     │
#              │ Similarity Search   │
#              │ Top-K = 3           │
#              └──────────┬──────────┘
#                         │
#                         ▼
#              ┌─────────────────────┐
#              │  Relevant Chunks    │
#              │                     │
#              │ Retrieved Context   │
#              │ + Page Metadata     │
#              └──────────┬──────────┘
#                         │
#                         ▼
#              ┌─────────────────────┐
#              │ Prompt Construction │
#              │                     │
#              │ Context + Question  │
#              └──────────┬──────────┘
#                         │
#                         ▼
#              ┌─────────────────────┐
#              │     GPT-4o-mini     │
#              │                     │
#              │ Context-Grounded    │
#              │ Answer Generation   │
#              └──────────┬──────────┘
#                         │
#                         ▼
#              ┌─────────────────────┐
#              │   Final Response    │
#              │                     │
#              │ Answer + Sources    │
#              └─────────────────────┘

# %% [markdown]
# ## Task 1 — Load the PDF
#
# ### Goal
# Load the supplied PDF using LangChain's PDF loader.
#
# ### Your tasks
# 1. Import the PDF loader.
# 2. Set the PDF path.
# 3. Create the loader.
# 4. Load the documents.
# 5. Display the number of pages.
# 6. Display the first page.
# 7. Display the first page metadata.
#
# ### Hint 1
# The loader is available from `langchain_community.document_loaders`.
#
# ### Hint 2
# The class name starts with `PyPDF...`.
#
# ### Hint 3
# The loader uses a `.load()` method.
#
# ### Expected result
# You should see the number of PDF pages, page text, and metadata.

# %%
# Task 1 - Import the PDF loader
# TODO: Complete the import

# %%
# Task 1 - Set the PDF path
pdf_path = "../04_DATA/sample_knowledge_base.pdf"

# %%
# Task 1 - Create the loader
# TODO: Create the PDF loader using pdf_path

# %%
# Task 1 - Load the PDF
# TODO: Load the documents

# %%
# Task 1 - Inspect the loaded document
# TODO: Print number of pages, first page content and metadata

# %% [markdown]
# ## Task 2 — Split the Document into Chunks
#
# ### Goal
# Split the loaded PDF into fixed-size chunks.
#
# ### Required configuration
# - Chunk size: **1000**
# - Chunk overlap: **200**
#
# ### Your tasks
# 1. Import `RecursiveCharacterTextSplitter`.
# 2. Set the chunk size and overlap.
# 3. Create the text splitter.
# 4. Split the documents.
# 5. Display the number of chunks.
# 6. Display sample chunk content and metadata.
#
# ### Mini experiment
# After the main implementation works, try:
# - `chunk_size = 500`
# - `chunk_overlap = 100`
#
# Compare the number of chunks.

# %%
# Task 2 - Import the text splitter
# TODO

# %%
# Task 2 - Configure chunking
chunk_size = 1000
chunk_overlap = 200

# %%
# Task 2 - Create the splitter
# TODO

# %%
# Task 2 - Split documents
# TODO

# %%
# Task 2 - Inspect chunks
# TODO: print number of chunks and the first 2 chunks

# %% [markdown]
# ## Task 3 — Generate Embeddings and Store in ChromaDB
#
# ### Goal
# Generate embeddings using `text-embedding-3-small` and store the chunks in ChromaDB.
#
# ### Your tasks
# 1. Import `OpenAIEmbeddings`.
# 2. Create the embedding model.
# 3. Import `Chroma`.
# 4. Create a Chroma vector store using the chunks.
# 5. Store the database in `../chroma_db`.
# 6. Perform a similarity search.
#
# ### Hints
# - Embedding class: `OpenAIEmbeddings`
# - Model: `text-embedding-3-small`
# - Chroma package: `langchain_chroma`
# - Similarity search method: `similarity_search(query, k=3)`

# %%
# Task 3 - Import the embedding class
# TODO

# %%
# Task 3 - Create embeddings
# TODO: use text-embedding-3-small

# %%
# Task 3 - Import Chroma
# TODO

# %%
# Task 3 - Create the vector store
# TODO: store chunks in ../chroma_db

# %%
# Task 3 - Test similarity search
query = "What is the purpose of this document?"

# TODO: perform similarity search and print the retrieved chunks

# %% [markdown]
# ## Task 4 — Build the RAG Question-Answering Pipeline
#
# ### Goal
# Connect ChromaDB retrieval to GPT-4o-mini.
#
# ### Required flow
# Question → Retriever → Relevant chunks → Context → GPT-4o-mini → Answer
#
# ### Your tasks
# 1. Load/create the embedding model.
# 2. Load ChromaDB.
# 3. Create a retriever with `k=3`.
# 4. Initialize GPT-4o-mini.
# 5. Create a prompt that tells the model to use **only the retrieved context**.
# 6. Ask a question.
# 7. Retrieve relevant chunks.
# 8. Build the context.
# 9. Invoke the LLM.
# 10. Display the answer and source pages.
#
# ### Grounding requirement
# If the answer is not available in the retrieved context, the model should respond:
#
# > I could not find the answer in the provided document.

# %%
# Task 4 - Imports
# TODO: import OpenAIEmbeddings, ChatOpenAI, Chroma and ChatPromptTemplate

# %%
# Task 4 - Load ChromaDB
# TODO

# %%
# Task 4 - Create retriever
# TODO: use k=3

# %%
# Task 4 - Initialize GPT-4o-mini
# TODO: temperature should be 0

# %%
# Task 4 - Create the grounded prompt
# TODO: create a ChatPromptTemplate
# The prompt must instruct the model to answer only from the context.

# %%
# Task 4 - Ask a question
question = "What is the purpose of this document?"

# TODO: retrieve relevant documents

# %%
# Task 4 - Build context
# TODO: join the retrieved document page_content values

# %%
# Task 4 - Invoke GPT-4o-mini
# TODO: format the prompt and invoke the LLM

# %%
# Task 4 - Display answer and sources
# TODO

# %% [markdown]
# ## Task 5 — Build an Interactive RAG Application
#
# Create a single Python script named:
#
# `rag_app.py`
#
# The application should:
# 1. Load the supplied PDF.
# 2. Chunk the document.
# 3. Generate embeddings.
# 4. Store them in ChromaDB.
# 5. Create a retriever.
# 6. Ask questions interactively.
# 7. Generate grounded answers using GPT-4o-mini.
# 8. Display source pages.
# 9. Exit when the user types `exit`.
#
# ### Validation questions
# Test at least:
# 1. A question whose answer exists in the PDF.
# 2. A second question about another section.
# 3. A question whose answer does not exist in the PDF.
#
# ### Success criteria
# The application should return relevant answers for document-based questions and refuse to invent an answer when the information is not available.

# %%
# Task 5
# Create your complete rag_app.py implementation here.
# You may combine and refactor the code developed in Tasks 1-4.

# %% [markdown]
# ## Final Validation Checklist
#
# - [ ] PDF loads successfully.
# - [ ] Number of pages is displayed.
# - [ ] Document chunks are created.
# - [ ] Chunk size is 1000.
# - [ ] Chunk overlap is 200.
# - [ ] `text-embedding-3-small` is used.
# - [ ] ChromaDB contains the document embeddings.
# - [ ] Similarity retrieval returns relevant chunks.
# - [ ] GPT-4o-mini is used.
# - [ ] Answers are based only on retrieved context.
# - [ ] Source page numbers are displayed.
# - [ ] Out-of-context question is handled correctly.
# - [ ] Final interactive RAG application runs successfully.
